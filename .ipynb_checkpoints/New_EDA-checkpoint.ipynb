# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
import folium
import datetime as dt

# %matplotlib inline
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

plt.style.use('ggplot')
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]

import warnings
warnings.filterwarnings(action='ignore')

from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.cluster import KMeans, DBSCAN
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

import folium

# %%
raw_df = pd.read_csv('new_jan_1.csv')

# %%
raw_df.head()
# Out:
#    taxi_id  trip_seconds   fare  tips  tolls  extras  trip_total  \
# 0     85.0         180.0   4.50   0.0    0.0     0.0        4.50
# 1   4237.0         480.0   7.00   0.0    0.0     0.0        7.00
# 2   1987.0        1080.0  17.75   0.0    0.0     0.0       17.75
# 3   6400.0          60.0   3.75   0.0    0.0     0.0        3.75
# 4   7418.0         180.0   5.00   2.0    0.0     1.5        8.50
#
#    pickup_latitude  pickup_longitude  dropoff_latitude  dropoff_longitude  \
# 0            199.0             510.0             199.0              510.0
# 1            686.0             500.0             686.0              500.0
# 2            599.0             346.0             660.0              120.0
# 3            527.0              24.0             527.0               24.0
# 4            210.0             470.0             744.0              605.0
#
#    trip_minuate   trip_km
# 0           3.0  0.643700
# 1           8.0  1.770300
# 2          18.0  9.977900
# 3           1.0  0.321900
# 4           3.0  1.001646

# %%
df = raw_df[['fare', 'tips', 'tolls', 'extras', 'trip_total', 'trip_km', 'trip_minuate']]

# %%
# 주행거리가 0인 데이터를 랜덤포레스트를 통해 채워넣은 데이터
df[df['trip_km']==0].__len__()
# Out:
# 0

# %%
# 주행요금이 0인 데이터 삭제
df = df.loc[df['trip_total']!=0, :]

# %%
plt.figure(figsize=(7,7))
mask=df.iloc[:,2:].corr() > 0.3
sns.heatmap(df.iloc[:,2:].corr(),cmap='YlGnBu',mask=mask,fmt='.1g')

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# fare            0
# tips            0
# tolls           0
# extras          0
# trip_total      0
# trip_km         0
# trip_minuate    0
# dtype: int64

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
sns.scatterplot(data=df, x='trip_km', y='trip_total', ax=ax[0], color=color_pal[2] ,alpha=0.4)
ax[0].set_xlim(-1,10)
ax[0].set_ylim(-25,250)

sns.scatterplot(data=df, x='trip_km', y='trip_total', ax=ax[1], color='cornflowerblue', alpha=0.4)
ax[1].set_xlim(-10,500)
ax[1].set_ylim(-25,500)
# Out:
# (-25.0, 500.0)

# %% [markdown]
# #### 표준화 및 역할 정의

# %%
X_list = list(df.columns)
X_list.remove('trip_total')

# 데이터 표준화
scaler = StandardScaler()
# 목표변수 y를 trip_total로 설정

df_raw_x = scaler.fit_transform(df[X_list])
df_raw_y = scaler.fit_transform(df[['trip_total']])

# %% [markdown]
# ## k-평균 군집분석

# %% [markdown]
# #### 군집 개수 찾기 : 각 데이터로부터 가장 가까운 군집 중심점까지의 거리 제곱합

# %%
# 최대 군집 생성 개수
n_iter_cluster = 5
cluster_range = [i+1 for i in range(n_iter_cluster)]
clus_error = []
for v_n_clus in cluster_range : 
    clus = KMeans(v_n_clus)
    clus.fit(df_raw_x)
    # 각 데이터로 부터 가장 가까운 군집 중심점까지 거리 제곱합
    clus_error.append(clus.inertia_)
ds_error = pd.DataFrame({'NumberofCluster' : cluster_range,
                        'Error' : clus_error})
ds_error
# Out:
#    NumberofCluster         Error
# 0                1  8.301174e+06
# 1                2  7.016575e+06
# 2                3  5.779925e+06
# 3                4  4.569877e+06
# 4                5  3.478294e+06

# %% [markdown]
# #### 4-2) 군집별 군집 중시점까지 거리 제곱합 시각화

# %%
plt.figure(figsize = (10,10))
plt.plot(ds_error['NumberofCluster'], ds_error['Error'])
plt.title("Sum of squared distance")
plt.xlabel('Cluster')
plt.ylabel('Sum of squared distance')
# Out:
# Text(0, 0.5, 'Sum of squared distance')

# %% [markdown]
# #### 4-3) k-평균 군집 번호 생성

# %%
clus = KMeans(5)
clus.fit(df_raw_x)
cluster_kmeans = [i+1 for i in clus.labels_]
df['ClusterKmeans'] = cluster_kmeans
df.head()
# Out:
#     fare  tips  tolls  extras  trip_total   trip_km  trip_minuate  \
# 0   4.50   0.0    0.0     0.0        4.50  0.643700           3.0
# 1   7.00   0.0    0.0     0.0        7.00  1.770300           8.0
# 2  17.75   0.0    0.0     0.0       17.75  9.977900          18.0
# 3   3.75   0.0    0.0     0.0        3.75  0.321900           1.0
# 4   5.00   2.0    0.0     1.5        8.50  1.001646           3.0
#
#    ClusterKmeans
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# #### 4-4) k-평균 군집별 데이터 요약

# %%
ds_summary_km = df.groupby("ClusterKmeans").agg(['min','mean','max'])
level0 = ds_summary_km.columns.get_level_values(0)
level1 = ds_summary_km.columns.get_level_values(1)
ds_summary_km.columns = level0 + '_' + level1
ds_summary_km.reset_index(inplace = True)
ds_summary_km.round(3)
# Out:
#    ClusterKmeans  fare_min  fare_mean  fare_max  tips_min  tips_mean  \
# 0              1      0.00      9.793    300.00       0.0      0.794
# 1              2      0.00     38.859   3186.50       0.0      7.760
# 2              3    999.99   6092.759   9002.29       0.0      0.000
# 3              4      3.25      8.784     33.75       0.0      0.000
# 4              5     17.85     38.157     73.25       0.0      5.242
#
#    tips_max  tolls_min  tolls_mean  tolls_max  ...  extras_max  \
# 0      7.00        0.0       0.001      75.00  ...     1556.55
# 1    369.08        0.0       0.006      75.00  ...      101.00
# 2      0.00        0.0      78.571     999.99  ...      999.99
# 3      0.00        0.0       0.000       0.00  ...     9993.41
# 4     25.00        0.0       0.000       0.00  ...        5.00
#
#    trip_total_min  trip_total_mean  trip_total_max  trip_km_min  trip_km_mean  \
# 0            0.01           11.107         1562.55        0.016         3.678
# 1            0.70           49.485         3186.50        0.016        22.245
# 2         2999.97         6207.133         9052.39        0.161        38.998
# 3         3336.58         5533.045         9997.16        0.322         5.264
# 4           18.25           46.062           94.38     1223.101      2419.800
#
#    trip_km_max  trip_minuate_min  trip_minuate_mean  trip_minuate_max
# 0      370.149               0.0              9.574              67.0
# 1     1207.008               0.0             33.555            1439.0
# 2     1006.001               3.0             14.143              56.0
# 3       18.025               0.0              6.839              24.0
# 4     4828.032               1.0             30.566              74.0
#
# [5 rows x 22 columns]

# %%
tmp = df.groupby('ClusterKmeans')[['trip_total']].count().rename(columns={'trip_total':'counts'})
plt.figure(figsize=(10,6))
plt.bar(tmp.index, tmp.counts)

for x, y in zip(tmp.index, tmp.counts):
    label = "{0}".format(y)
    plt.annotate(label, (x,y), textcoords='offset pixels', 
                 xytext=(0,10), 
                 ha='center')

# %% [markdown]
# ## 군집 1, 2, 3에 대한 군집 특성 확인

# %%
df1 = df[df['ClusterKmeans']==1]
df2 = df[df['ClusterKmeans']==2]
df3 = df[df['ClusterKmeans']==5]

# %%
df1.describe()
# Out:
#                fare          tips         tolls        extras    trip_total  \
# count  1.277638e+06  1.277638e+06  1.277638e+06  1.277638e+06  1.277638e+06
# mean   9.792794e+00  7.940933e-01  1.006733e-03  5.191725e-01  1.110709e+01
# std    7.365945e+00  1.190027e+00  2.147517e-01  3.080342e+00  8.346981e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e-02
# 25%    5.750000e+00  0.000000e+00  0.000000e+00  0.000000e+00  6.750000e+00
# 50%    7.500000e+00  0.000000e+00  0.000000e+00  0.000000e+00  8.750000e+00
# 75%    1.075000e+01  2.000000e+00  0.000000e+00  1.000000e+00  1.250000e+01
# max    3.000000e+02  7.000000e+00  7.500000e+01  1.556550e+03  1.562550e+03
#
#             trip_km  trip_minuate  ClusterKmeans
# count  1.277638e+06  1.277638e+06      1277638.0
# mean   3.677577e+00  9.573920e+00            1.0
# std    7.117505e+00  7.031454e+00            0.0
# min    1.610000e-02  0.000000e+00            1.0
# 25%    1.126500e+00  5.000000e+00            1.0
# 50%    1.931200e+00  8.000000e+00            1.0
# 75%    3.701500e+00  1.200000e+01            1.0
# max    3.701491e+02  6.700000e+01            1.0

# %%
def quantile_data(data):
    quan = list(data['trip_total'].quantile([0.25, 0.75]))
    result = data[(data['trip_total'] >= quan[0]) & (data['trip_total'] <= quan[1])]
    return result

# %%
df1 = quantile_data(df1)
df2 = quantile_data(df2)
df3 = quantile_data(df3)
data = [df1, df2, df3]

# %%
df1['trip_total'].quantile([0.25, 0.75])
# Out:
# 0.25     7.75
# 0.75    10.25
# Name: trip_total, dtype: float64

# %%
fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(26,15))
data = [df1, df2, df3]
for idx, d in enumerate(data):

    sns.heatmap(d.corr(),cmap='YlGnBu',fmt='.1g', ax=ax[idx,0])
    sns.boxplot(d[['trip_total', 'trip_km', 'trip_minuate']], orient='v', ax=ax[idx,1])
    sns.distplot(d.trip_total, ax=ax[idx,2], color=color_pal[1])
    sns.scatterplot(data=d, y='trip_total', x='trip_km', ax=ax[idx,3], alpha=0.5, color=color_pal[2])
    
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.2)
